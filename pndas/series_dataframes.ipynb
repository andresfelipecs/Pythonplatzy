# %% [markdown]
# ### Importar librería

# %%
import pandas as pd

# %% [markdown]
# ### Crear serie

# %%
psg_players = pd.Series(['Navas','Mbappe','Neymar','Messi'],
          index=[1,7,10,30]
          )

# %%
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players = pd.Series(['Navas','Mbappe','Neymar','Messi']
          )

# %%
psg_players[3]
# Out:
# 'Messi'

# %%
psg_players
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# 3     Messi
# dtype: object

# %%
dict = {1:'Navas',7:'Mbappe',10:'Neymar',30:'Messi'}
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[0:3]
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# dtype: object

# %% [markdown]
# ### Crear DataFrame

# %%
dict = {'Jugador':['Navas','Mbappe','Neymar','Messi'],
 'Altura':[183.0, 170.0, 170.0, 165.0],
 'Goles':[2,200,200,200]
 }

# %%
df_Players = pd.DataFrame(dict,index=[1,7,10,30])

# %%
df_Players
# Out:
#    Jugador  Altura  Goles
# 1    Navas   183.0      2
# 7   Mbappe   170.0    200
# 10  Neymar   170.0    200
# 30   Messi   165.0    200

# %%
df_Players.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %%
df_Players.index
# Out:
# Int64Index([1, 7, 10, 30], dtype='int64')

# %%
dict = {'Jugador':['Luis SuÃ¡rez','Jorge Molina', 'Antonio Puertas', 'GermÃ¡n SÃ¡nchez', 'Luis Milla', 'LuÃ­s Manuel Arantes Maximiano'],

'Posicionn':['Delantero', 'Delantero', 'Centrocampista', 'Defensa', 'Centrocampista', 'Portero'],

'Numero':[9, 23, 10, 6, 5, 1],

'Altura':[185.0, 187.0, 185.0, 187.0, 175.0, 190.0],

'Goles':[7, 7, 5, 2, 2, 0] }

# %%
df_player = pd.DataFrame(dict)
df_player
# Out:
#                           Jugador       Posicionn  Numero  Altura  Goles
# 0                    Luis SuÃ¡rez       Delantero       9   185.0      7
# 1                    Jorge Molina       Delantero      23   187.0      7
# 2                 Antonio Puertas  Centrocampista      10   185.0      5
# 3                GermÃ¡n SÃ¡nchez         Defensa       6   187.0      2
# 4                      Luis Milla  Centrocampista       5   175.0      2
# 5  LuÃ­s Manuel Arantes Maximiano         Portero       1   190.0      0

# %%
df_player.columns
# Out:
# Index(['Jugador', 'Posicionn', 'Numero', 'Altura', 'Goles'], dtype='object')

# %%
df_player.index
# Out:
# RangeIndex(start=0, stop=6, step=1)
